# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahjabeenqamar1/OPEN_CV/blob/main/Image_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
#image=cv2.imread('/content/drive/MyDrive/index.jpeg')

# %%
image
# Out:
# array([[[ 25,  27,  62],
#         [ 25,  27,  62],
#         [ 25,  27,  62],
#         ...,
#         [  1, 104, 159],
#         [  0, 101, 158],
#         [  0,  99, 156]],
#
#        [[ 25,  27,  62],
#         [ 25,  27,  62],
#         [ 25,  27,  62],
#         ...,
#         [  2, 108, 162],
#         [  0, 104, 161],
#         [  0, 103, 160]],
#
#        [[ 25,  27,  62],
#         [ 25,  27,  62],
#         [ 25,  27,  62],
#         ...,
#         [  4, 113, 169],
#         [  2, 111, 167],
#         [  0, 109, 165]],
#
#        ...,
#
#        [[ 20,  20,  56],
#         [ 20,  20,  56],
#         [ 21,  21,  57],
#         ...,
#         [ 22,  75, 125],
#         [ 19,  72, 122],
#         [ 15,  71, 120]],
#
#        [[ 20,  20,  56],
#         [ 20,  20,  56],
#         [ 21,  21,  57],
#         ...,
#         [ 24,  75, 125],
#         [ 19,  72, 122],
#         [ 17,  70, 120]],
#
#        [[ 21,  21,  57],
#         [ 21,  21,  57],
#         [ 21,  21,  57],
# ...

# %%
image.shape
# Out:
# (185, 272, 3)

# %%
plt.imshow(image)

# %%
im_resized = cv2.resize(image, (224, 224))

# %%
im_resized
# Out:
# array([[[ 25,  27,  62],
#         [ 25,  27,  62],
#         [ 25,  27,  62],
#         ...,
#         [  1, 104, 159],
#         [  0, 102, 158],
#         [  0,  99, 156]],
#
#        [[ 25,  27,  62],
#         [ 25,  27,  62],
#         [ 25,  27,  62],
#         ...,
#         [  3, 107, 162],
#         [  0, 104, 160],
#         [  0, 102, 159]],
#
#        [[ 25,  27,  62],
#         [ 25,  27,  62],
#         [ 25,  27,  62],
#         ...,
#         [  4, 111, 166],
#         [  2, 109, 165],
#         [  0, 106, 163]],
#
#        ...,
#
#        [[ 20,  20,  56],
#         [ 20,  20,  56],
#         [ 21,  21,  57],
#         ...,
#         [ 24,  76, 126],
#         [ 20,  73, 123],
#         [ 16,  71, 120]],
#
#        [[ 20,  20,  56],
#         [ 20,  20,  56],
#         [ 21,  21,  57],
#         ...,
#         [ 24,  75, 125],
#         [ 20,  72, 123],
#         [ 18,  70, 121]],
#
#        [[ 21,  21,  57],
#         [ 21,  21,  57],
#         [ 21,  21,  57],
# ...

# %%
im = cv2.imread('/content/drive/MyDrive/index.jpeg')

# %%
im_resized = cv2.resize(im, (224, 224), interpolation=cv2.INTER_LINEAR)

# %%
plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))

# %%
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

im = cv2.imread('/content/drive/MyDrive/face.jpeg')

#im_resized = cv2.resize(im, (224, 224), interpolation=cv2.INTER_LINEAR)

plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
#plt.imshow(im_resized[:100,:100],cmap ="gray")
plt.show()

# %%
plt.imshow()

# %%
#image = cv2.imread("/content/drive/MyDrive/face.jpeg")
image = cv2.imread("/content/drive/MyDrive/Real& fake/Real_Fake_result/train/fake/0 (1).jpg")
#gray = cv2.cvtColor(image, cv2.COLOR_BAYER_GB2BGR)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_

# %%
plt.imshow(gray[70:120,140:170],cmap='gray')

# %%
import cv2

# %%
image = cv2.imread("/content/drive/MyDrive/face.jpeg")

# %%
# cv2.rectangle(image,(200,200),(400,400),(0,255,0),3)
# cv2.imshow("image",image)
# # cv2.waltkey(0)
# cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-47449f4c2015> in <module>()
# ----> 1 cv2.rectangle(image,(200,200),(400,400),(0,255,0),3)
#       2 cv2.imshow("image",image)
#       3 # cv2.waltkey(0)
#       4 # cv2.destroyAllWindows()
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# ##Add or Blend two image with OpenCV

# %%
import cv2

# %% [markdown]
# read two images

# %%
scr1 = cv2.imread('/content/drive/MyDrive/face.jpeg',cv2.IMREAD_COLOR)
scr2 = cv2.imread('/content/drive/MyDrive/index.jpeg',cv2.IMREAD_COLOR)

# %%
dim1 = cv2.resize(scr1,(120,120))
dim2 = cv2.resize(scr2,(120,120))

# %% [markdown]
# Add or Blend two image

# %%
dst = cv2.addWeighted(scr1, 0.5, scr2, 0.5, 0.0)

# %%
# import cv2
 
# img = cv2.imread('images.jpeg', cv2.IMREAD_UNCHANGED)
 
# print('Original Dimensions : ',img.shape)
 
# width = 440
# height = img.shape[0] # keep original height
# dim = (width, height)
 
# # resize image
# resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
# print('Resized Dimensions : ',resized.shape)
 
# cv2.imshow("Resized image", resized)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
#cv2.imwrite('image.jpg',dst)
